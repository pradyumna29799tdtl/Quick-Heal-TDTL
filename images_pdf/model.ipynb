# %% [markdown]
# Import the Required Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %% [markdown]
# Load the Image Training and Validation Datasets

# %%
train_dataset_path = r'C:\Users\PradyumnaBadave\Downloads\Dataset (1)\Dataset\train'
validation_dataset_path = r'C:\Users\PradyumnaBadave\Downloads\Dataset (1)\Dataset\test'

# %%
import os
from PIL import Image

def verify_images(directory):
    for root, dirs, files in os.walk(directory):
        for filename in files:
            if filename.lower().endswith(('.jpg', '.jpeg','.JPG')):
                file_path = os.path.join(root, filename)
                try:
                    img = Image.open(file_path)
                    img.verify()  # Verify if it's a valid image
                except (IOError, SyntaxError) as e:
                    print(f"Bad file: {file_path}")
                    os.remove(file_path)  # Optionally remove bad files
            else:
                os.remove(os.path.join(root, filename))  # Remove non-JPEG files

# Verify images in both train and validation directories
verify_images(train_dataset_path)
verify_images(validation_dataset_path)

# %%
IMG_WIDTH = 150
IMG_HEIGHT = 150
BATCH_SIZE = 32

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                  zoom_range=0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  fill_mode='nearest')
train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 1176 images belonging to 6 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1.0/255)
validation_generator = validation_datagen.flow_from_directory(validation_dataset_path,
                                                             target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                             batch_size=BATCH_SIZE,
                                                             class_mode='categorical',
                                                             shuffle=True)
# Out:
# Found 214 images belonging to 6 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classes present in the training and validation datasets\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classes present in the training and validation datasets
#
# 0 : Aadhaar
# 1 : Driving Licence
# 2 : PAN
# 3 : Passport
# 4 : Utility
# 5 : Voter ID

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15, 12))
idx = 0

for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label}")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
def create_model():
    model = Sequential([
        Conv2D(filters=128, kernel_size=(5, 5), padding='valid', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=64, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(filters=32, kernel_size=(3, 3), padding='valid', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(units=256, activation='relu'),
        Dropout(0.5),
        Dense(units=6, activation='softmax')
    ])
    
    return model

# %%
cnn_model = create_model()

# %%
print(cnn_model.summary())
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 146, 146, 128)  │         9,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 146, 146, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 73, 73, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 73, 73, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 71, 71, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 71, 71, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 35, 35, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 35, 35, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 33, 33, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 33, 33, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 16, 16, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │         1,542 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,201,830 (8.40 MB)
#  Trainable params: 2,201,382 (8.40 MB)
#  Non-trainable params: 448 (1.75 KB)
# None

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), patience=5)

# %%
optimizer = Adam(learning_rate=0.001)

# %%
cnn_model.compile(optimizer=optimizer, loss=CategoricalCrossentropy(), metrics=['accuracy'])

# %%
history = cnn_model.fit(train_generator, epochs=100, validation_data=validation_generator,
                       verbose=2,
                       callbacks=[reduce_lr])
# Out:
# Epoch 1/100
# 37/37 - 121s - 3s/step - accuracy: 0.4396 - loss: 3.2454 - val_accuracy: 0.1121 - val_loss: 2.5399 - learning_rate: 0.0010
# Epoch 2/100
# 37/37 - 105s - 3s/step - accuracy: 0.5893 - loss: 2.4794 - val_accuracy: 0.0981 - val_loss: 3.1151 - learning_rate: 0.0010
# Epoch 3/100
# 37/37 - 101s - 3s/step - accuracy: 0.5901 - loss: 2.1917 - val_accuracy: 0.1262 - val_loss: 2.3582 - learning_rate: 0.0010
# Epoch 4/100
# 37/37 - 102s - 3s/step - accuracy: 0.6582 - loss: 1.7655 - val_accuracy: 0.1121 - val_loss: 3.0023 - learning_rate: 0.0010
# Epoch 5/100
# 37/37 - 107s - 3s/step - accuracy: 0.7049 - loss: 1.2888 - val_accuracy: 0.1402 - val_loss: 3.1100 - learning_rate: 0.0010
# Epoch 6/100
# 37/37 - 100s - 3s/step - accuracy: 0.7211 - loss: 1.1493 - val_accuracy: 0.1916 - val_loss: 3.0996 - learning_rate: 0.0010
# Epoch 7/100
# 37/37 - 99s - 3s/step - accuracy: 0.7526 - loss: 0.9122 - val_accuracy: 0.1449 - val_loss: 5.8040 - learning_rate: 0.0010
# Epoch 8/100
# 37/37 - 100s - 3s/step - accuracy: 0.7543 - loss: 0.9449 - val_accuracy: 0.3738 - val_loss: 1.6781 - learning_rate: 0.0010
# Epoch 9/100
# 37/37 - 99s - 3s/step - accuracy: 0.7560 - loss: 0.9058 - val_accuracy: 0.5093 - val_loss: 1.2481 - learning_rate: 0.0010
# Epoch 10/100
# 37/37 - 99s - 3s/step - accuracy: 0.7772 - loss: 0.8436 - val_accuracy: 0.5935 - val_loss: 1.3055 - learning_rate: 0.0010
# Epoch 11/100
# 37/37 - 108s - 3s/step - accuracy: 0.8010 - loss: 0.6930 - val_accuracy: 0.7477 - val_loss: 0.7619 - learning_rate: 0.0010
# Epoch 12/100
# 37/37 - 107s - 3s/step - accuracy: 0.7798 - loss: 0.6704 - val_accuracy: 0.5561 - val_loss: 1.5721 - learning_rate: 0.0010
# Epoch 13/100
# 37/37 - 130s - 4s/step - accuracy: 0.8095 - loss: 0.5974 - val_accuracy: 0.6869 - val_loss: 0.8614 - learning_rate: 0.0010
# Epoch 14/100
# 37/37 - 118s - 3s/step - accuracy: 0.8469 - loss: 0.5077 - val_accuracy: 0.6495 - val_loss: 1.4687 - learning_rate: 0.0010
# Epoch 15/100
# 37/37 - 120s - 3s/step - accuracy: 0.8384 - loss: 0.5631 - val_accuracy: 0.8084 - val_loss: 0.6073 - learning_rate: 0.0010
# Epoch 16/100
# 37/37 - 125s - 3s/step - accuracy: 0.8325 - loss: 0.5470 - val_accuracy: 0.6168 - val_loss: 1.8464 - learning_rate: 0.0010
# Epoch 17/100
# 37/37 - 120s - 3s/step - accuracy: 0.8580 - loss: 0.4576 - val_accuracy: 0.7336 - val_loss: 1.0400 - learning_rate: 0.0010
# Epoch 18/100
# 37/37 - 119s - 3s/step - accuracy: 0.8342 - loss: 0.4958 - val_accuracy: 0.7430 - val_loss: 0.8269 - learning_rate: 0.0010
# Epoch 19/100
# 37/37 - 114s - 3s/step - accuracy: 0.8452 - loss: 0.4992 - val_accuracy: 0.8364 - val_loss: 0.4964 - learning_rate: 0.0010
# Epoch 20/100
# 37/37 - 114s - 3s/step - accuracy: 0.8759 - loss: 0.3923 - val_accuracy: 0.8738 - val_loss: 0.4499 - learning_rate: 0.0010
# Epoch 21/100
# 37/37 - 115s - 3s/step - accuracy: 0.8818 - loss: 0.3875 - val_accuracy: 0.7336 - val_loss: 2.1001 - learning_rate: 0.0010
# Epoch 22/100
# 37/37 - 116s - 3s/step - accuracy: 0.8699 - loss: 0.4458 - val_accuracy: 0.6682 - val_loss: 2.8814 - learning_rate: 0.0010
# Epoch 23/100
# 37/37 - 107s - 3s/step - accuracy: 0.8690 - loss: 0.4424 - val_accuracy: 0.6402 - val_loss: 3.2493 - learning_rate: 0.0010
# Epoch 24/100
# 37/37 - 102s - 3s/step - accuracy: 0.8733 - loss: 0.4249 - val_accuracy: 0.2103 - val_loss: 29.0360 - learning_rate: 0.0010
# Epoch 25/100
# 37/37 - 117s - 3s/step - accuracy: 0.8733 - loss: 0.3875 - val_accuracy: 0.4813 - val_loss: 9.2170 - learning_rate: 0.0010
# Epoch 26/100
# 37/37 - 109s - 3s/step - accuracy: 0.8920 - loss: 0.3643 - val_accuracy: 0.6822 - val_loss: 2.8157 - learning_rate: 3.1623e-04
# Epoch 27/100
# 37/37 - 111s - 3s/step - accuracy: 0.9048 - loss: 0.2830 - val_accuracy: 0.8411 - val_loss: 0.6946 - learning_rate: 3.1623e-04
# Epoch 28/100
# 37/37 - 107s - 3s/step - accuracy: 0.9124 - loss: 0.2661 - val_accuracy: 0.8131 - val_loss: 1.2900 - learning_rate: 3.1623e-04
# Epoch 29/100
# 37/37 - 108s - 3s/step - accuracy: 0.9252 - loss: 0.2298 - val_accuracy: 0.8692 - val_loss: 0.4982 - learning_rate: 3.1623e-04
# Epoch 30/100
# 37/37 - 105s - 3s/step - accuracy: 0.9235 - loss: 0.2363 - val_accuracy: 0.9159 - val_loss: 0.3602 - learning_rate: 3.1623e-04
# Epoch 31/100
# 37/37 - 120s - 3s/step - accuracy: 0.9260 - loss: 0.2355 - val_accuracy: 0.7991 - val_loss: 1.2579 - learning_rate: 3.1623e-04
# Epoch 32/100
# 37/37 - 106s - 3s/step - accuracy: 0.9320 - loss: 0.1919 - val_accuracy: 0.8037 - val_loss: 1.0574 - learning_rate: 3.1623e-04
# Epoch 33/100
# 37/37 - 100s - 3s/step - accuracy: 0.9328 - loss: 0.2207 - val_accuracy: 0.8271 - val_loss: 1.0202 - learning_rate: 3.1623e-04
# Epoch 34/100
# 37/37 - 106s - 3s/step - accuracy: 0.9388 - loss: 0.1959 - val_accuracy: 0.8879 - val_loss: 0.4376 - learning_rate: 3.1623e-04
# Epoch 35/100
# 37/37 - 100s - 3s/step - accuracy: 0.9303 - loss: 0.1942 - val_accuracy: 0.9019 - val_loss: 0.4004 - learning_rate: 3.1623e-04
# Epoch 36/100
# 37/37 - 101s - 3s/step - accuracy: 0.9447 - loss: 0.1637 - val_accuracy: 0.9252 - val_loss: 0.2801 - learning_rate: 1.0000e-04
# Epoch 37/100
# 37/37 - 103s - 3s/step - accuracy: 0.9473 - loss: 0.1781 - val_accuracy: 0.8972 - val_loss: 0.5501 - learning_rate: 1.0000e-04
# Epoch 38/100
# 37/37 - 101s - 3s/step - accuracy: 0.9354 - loss: 0.1936 - val_accuracy: 0.8972 - val_loss: 0.5032 - learning_rate: 1.0000e-04
# Epoch 39/100
# 37/37 - 102s - 3s/step - accuracy: 0.9405 - loss: 0.1913 - val_accuracy: 0.8738 - val_loss: 0.6703 - learning_rate: 1.0000e-04
# Epoch 40/100
# 37/37 - 102s - 3s/step - accuracy: 0.9388 - loss: 0.1620 - val_accuracy: 0.9206 - val_loss: 0.2731 - learning_rate: 1.0000e-04
# Epoch 41/100
# 37/37 - 101s - 3s/step - accuracy: 0.9566 - loss: 0.1542 - val_accuracy: 0.9299 - val_loss: 0.2361 - learning_rate: 1.0000e-04
# Epoch 42/100
# 37/37 - 102s - 3s/step - accuracy: 0.9507 - loss: 0.1779 - val_accuracy: 0.9299 - val_loss: 0.3045 - learning_rate: 1.0000e-04
# Epoch 43/100
# 37/37 - 104s - 3s/step - accuracy: 0.9575 - loss: 0.1471 - val_accuracy: 0.9439 - val_loss: 0.2158 - learning_rate: 1.0000e-04
# Epoch 44/100
# 37/37 - 114s - 3s/step - accuracy: 0.9473 - loss: 0.1633 - val_accuracy: 0.9346 - val_loss: 0.2908 - learning_rate: 1.0000e-04
# Epoch 45/100
# 37/37 - 103s - 3s/step - accuracy: 0.9464 - loss: 0.1469 - val_accuracy: 0.9206 - val_loss: 0.2717 - learning_rate: 1.0000e-04
# Epoch 46/100
# 37/37 - 101s - 3s/step - accuracy: 0.9617 - loss: 0.1327 - val_accuracy: 0.9065 - val_loss: 0.3638 - learning_rate: 1.0000e-04
# Epoch 47/100
# 37/37 - 101s - 3s/step - accuracy: 0.9541 - loss: 0.1519 - val_accuracy: 0.8551 - val_loss: 0.8507 - learning_rate: 1.0000e-04
# Epoch 48/100
# 37/37 - 102s - 3s/step - accuracy: 0.9473 - loss: 0.1578 - val_accuracy: 0.9486 - val_loss: 0.2098 - learning_rate: 1.0000e-04
# Epoch 49/100
# 37/37 - 101s - 3s/step - accuracy: 0.9583 - loss: 0.1477 - val_accuracy: 0.8972 - val_loss: 0.3768 - learning_rate: 1.0000e-04
# Epoch 50/100
# 37/37 - 104s - 3s/step - accuracy: 0.9600 - loss: 0.1467 - val_accuracy: 0.9065 - val_loss: 0.3823 - learning_rate: 1.0000e-04
# Epoch 51/100
# 37/37 - 104s - 3s/step - accuracy: 0.9549 - loss: 0.1264 - val_accuracy: 0.8178 - val_loss: 1.0301 - learning_rate: 1.0000e-04
# Epoch 52/100
# 37/37 - 100s - 3s/step - accuracy: 0.9549 - loss: 0.1781 - val_accuracy: 0.9252 - val_loss: 0.2528 - learning_rate: 1.0000e-04
# Epoch 53/100
# 37/37 - 105s - 3s/step - accuracy: 0.9626 - loss: 0.1491 - val_accuracy: 0.8972 - val_loss: 0.4652 - learning_rate: 1.0000e-04
# Epoch 54/100
# 37/37 - 101s - 3s/step - accuracy: 0.9532 - loss: 0.1517 - val_accuracy: 0.9299 - val_loss: 0.2790 - learning_rate: 3.1623e-05
# Epoch 55/100
# 37/37 - 102s - 3s/step - accuracy: 0.9345 - loss: 0.1842 - val_accuracy: 0.9065 - val_loss: 0.3218 - learning_rate: 3.1623e-05
# Epoch 56/100
# 37/37 - 101s - 3s/step - accuracy: 0.9558 - loss: 0.1457 - val_accuracy: 0.9159 - val_loss: 0.3658 - learning_rate: 3.1623e-05
# Epoch 57/100
# 37/37 - 101s - 3s/step - accuracy: 0.9634 - loss: 0.1349 - val_accuracy: 0.9112 - val_loss: 0.4221 - learning_rate: 3.1623e-05
# Epoch 58/100
# 37/37 - 102s - 3s/step - accuracy: 0.9507 - loss: 0.1727 - val_accuracy: 0.9393 - val_loss: 0.2480 - learning_rate: 3.1623e-05
# Epoch 59/100
# 37/37 - 101s - 3s/step - accuracy: 0.9600 - loss: 0.1235 - val_accuracy: 0.9393 - val_loss: 0.2521 - learning_rate: 1.0000e-05
# Epoch 60/100
# 37/37 - 102s - 3s/step - accuracy: 0.9677 - loss: 0.1187 - val_accuracy: 0.9299 - val_loss: 0.2935 - learning_rate: 1.0000e-05
# Epoch 61/100
# 37/37 - 102s - 3s/step - accuracy: 0.9634 - loss: 0.1372 - val_accuracy: 0.9252 - val_loss: 0.3493 - learning_rate: 1.0000e-05
# Epoch 62/100
# 37/37 - 101s - 3s/step - accuracy: 0.9541 - loss: 0.1315 - val_accuracy: 0.9252 - val_loss: 0.3234 - learning_rate: 1.0000e-05
# Epoch 63/100
# 37/37 - 101s - 3s/step - accuracy: 0.9651 - loss: 0.1074 - val_accuracy: 0.9346 - val_loss: 0.2769 - learning_rate: 1.0000e-05
# Epoch 64/100
# 37/37 - 101s - 3s/step - accuracy: 0.9558 - loss: 0.1369 - val_accuracy: 0.9299 - val_loss: 0.2864 - learning_rate: 3.1623e-06
# Epoch 65/100
# 37/37 - 101s - 3s/step - accuracy: 0.9643 - loss: 0.1291 - val_accuracy: 0.9299 - val_loss: 0.2941 - learning_rate: 3.1623e-06
# Epoch 66/100
# 37/37 - 101s - 3s/step - accuracy: 0.9592 - loss: 0.1362 - val_accuracy: 0.9299 - val_loss: 0.2980 - learning_rate: 3.1623e-06
# Epoch 67/100
# 37/37 - 100s - 3s/step - accuracy: 0.9575 - loss: 0.1526 - val_accuracy: 0.9299 - val_loss: 0.3003 - learning_rate: 3.1623e-06
# Epoch 68/100
# 37/37 - 103s - 3s/step - accuracy: 0.9609 - loss: 0.1403 - val_accuracy: 0.9299 - val_loss: 0.3049 - learning_rate: 3.1623e-06
# Epoch 69/100
# 37/37 - 100s - 3s/step - accuracy: 0.9592 - loss: 0.1310 - val_accuracy: 0.9299 - val_loss: 0.3002 - learning_rate: 1.0000e-06
# Epoch 70/100
# 37/37 - 101s - 3s/step - accuracy: 0.9541 - loss: 0.1344 - val_accuracy: 0.9299 - val_loss: 0.2966 - learning_rate: 1.0000e-06
# Epoch 71/100
# 37/37 - 121s - 3s/step - accuracy: 0.9583 - loss: 0.1224 - val_accuracy: 0.9299 - val_loss: 0.2966 - learning_rate: 1.0000e-06
# Epoch 72/100
# 37/37 - 120s - 3s/step - accuracy: 0.9668 - loss: 0.1275 - val_accuracy: 0.9299 - val_loss: 0.2916 - learning_rate: 1.0000e-06
# Epoch 73/100
# 37/37 - 114s - 3s/step - accuracy: 0.9677 - loss: 0.1216 - val_accuracy: 0.9299 - val_loss: 0.2993 - learning_rate: 1.0000e-06
# Epoch 74/100
# 37/37 - 101s - 3s/step - accuracy: 0.9634 - loss: 0.1099 - val_accuracy: 0.9299 - val_loss: 0.2975 - learning_rate: 3.1623e-07
# Epoch 75/100
# 37/37 - 124s - 3s/step - accuracy: 0.9541 - loss: 0.1402 - val_accuracy: 0.9299 - val_loss: 0.2948 - learning_rate: 3.1623e-07
# Epoch 76/100
# 37/37 - 106s - 3s/step - accuracy: 0.9643 - loss: 0.1126 - val_accuracy: 0.9299 - val_loss: 0.2962 - learning_rate: 3.1623e-07
# Epoch 77/100
# 37/37 - 102s - 3s/step - accuracy: 0.9643 - loss: 0.1353 - val_accuracy: 0.9299 - val_loss: 0.2953 - learning_rate: 3.1623e-07
# Epoch 78/100
# 37/37 - 108s - 3s/step - accuracy: 0.9626 - loss: 0.1237 - val_accuracy: 0.9299 - val_loss: 0.2956 - learning_rate: 3.1623e-07
# Epoch 79/100
# 37/37 - 105s - 3s/step - accuracy: 0.9583 - loss: 0.1239 - val_accuracy: 0.9299 - val_loss: 0.2941 - learning_rate: 1.0000e-07
# Epoch 80/100
# 37/37 - 149s - 4s/step - accuracy: 0.9651 - loss: 0.1025 - val_accuracy: 0.9299 - val_loss: 0.2945 - learning_rate: 1.0000e-07
# Epoch 81/100
# 37/37 - 158s - 4s/step - accuracy: 0.9549 - loss: 0.1318 - val_accuracy: 0.9299 - val_loss: 0.2929 - learning_rate: 1.0000e-07
# Epoch 82/100

# %%
cnn_model.save('my_new_model.keras')

# %% [markdown]
# Plotting the Model Metrics¶

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

#learning_rate = history.history['reduce_lr']

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, figsize=(12, 10))

ax[0].set_title('Training Accuracy vs. Epochs')
ax[0].plot(train_accuracy, 'o-', label='Train Accuracy')
ax[0].plot(val_accuracy, 'o-', label='Validation Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc='best')

ax[1].set_title('Training/Validation Loss vs. Epochs')
ax[1].plot(train_loss, 'o-', label='Train Loss')
ax[1].plot(val_loss, 'o-', label='Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(loc='best')

# ax[2].set_title('Learning Rate vs. Epochs')
# ax[2].plot(learning_rate, 'o-', label='Learning Rate')
# ax[2].set_xlabel('Epochs')
# ax[2].set_ylabel('Loss')
# ax[2].legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# Testing the Model on Test Set

# %%
test_dataset = r'C:/Users/PradyumnaBadave/Downloads/Dataset (1)/Dataset/test'

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 419 images belonging to 7 classes.

# %% [markdown]
# Model Prediction on the Test Dataset

# %%
predictions = cnn_model.predict(test_generator)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 783ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = cnn_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 771ms/step - accuracy: 0.8921 - loss: 0.5036

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.3378745913505554
# Test Accuracy: 0.9284009337425232

# %% [markdown]
# Plotting the Classification Metrics

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
print("y_pred: ",y_pred)
print("y_true: ",y_true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print("y_pred: ",y_pred)
#       2 print("y_true: ",y_true)
#
# NameError: name 'y_pred' is not defined

# %%
cf_mtx = confusion_matrix(y_true, y_pred)

group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(6, 6)

plt.figure(figsize = (12, 10))
sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cf_mtx = confusion_matrix(y_true, y_pred)
#       3 group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
#       4 group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
#
# NameError: name 'confusion_matrix' is not defined

# %%
print(labels.values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(labels.values())
#
# NameError: name 'labels' is not defined

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 print(classification_report(y_true, y_pred, target_names=labels.values()))
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:2332, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2326         warnings.warn(
#    2327             "labels size, {0}, does not match size of target_names, {1}".format(
#    2328                 len(labels), len(target_names)
#    2329             )
#    2330         )
#    2331     else:
# -> 2332         raise ValueError(
#    2333             "Number of classes, {0}, does not match size of "
#    2334             "target_names, {1}. Try specifying the labels "
#    2335             "parameter".format(len(labels), len(target_names))
#    2336         )
#    2337 if target_names is None:
#    2338     target_names = ["%s" % l for l in labels]
#
# ValueError: Number of classes, 6, does not match size of target_names, 7. Try specifying the labels parameter

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=20)
plt.show()
